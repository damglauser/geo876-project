# %% [markdown]
# GLOBAL WILDFIRE RISK ANALYSIS WORKFLOW
# ---------------------------
#
# Research Question
#
# Where are high-intensity wildfire events occurring globally within the last 72 hours, and how high is the potential humanitarian risk based on distance to densely populated areas?

# %%
# ==========================================
# IMPORTS & NOTEBOOK SETUP
# ==========================================

import sys
from pathlib import Path

# Add src folder to Python path
sys.path.append("../src")

print("Imports completed successfully.")
# Out:
# Imports completed successfully.

# %%
# =========================================================
# STEP 1 — DOWNLOAD NASA FIRMS DATA
# =========================================================

from download_api_data import download_firms_data

gdf = download_firms_data()
# Out:
# Project root:
# C:\Users\Damian\OneDrive - Universität Zürich UZH\26 FS\GEO876 - Spatial Programming\GEO876_Project
#
# Output directory:
# C:\Users\Damian\OneDrive - Universität Zürich UZH\26 FS\GEO876 - Spatial Programming\GEO876_Project\data\raw
# Step 3: Requesting wildfire data from:
# https://firms.modaps.eosdis.nasa.gov/api/area/csv/cce9957f998431b07b2b2501061fc6aa/VIIRS_NOAA21_NRT/world/3
# Step 4: Data successfully downloaded.
#
# Step 5: Dataset successfully loaded.
# Number of wildfire detections: 66822
#
# Step 6: Geometry column successfully created.
#
# Step 7: First rows of dataset:
#    latitude longitude bright_ti4  scan track    acq_date acq_time satellite  \
# 0  64.84473  77.25401      326.8  0.76  0.77  2026-05-19       22       N21
# 1  64.64521  24.42774     313.68  0.52  0.41  2026-05-19       24       N21
# 2  65.56101  22.22275     306.34   0.4  0.44  2026-05-19       24       N21
# 3  65.56162  22.21415     315.47   0.4  0.44  2026-05-19       24       N21
# 4  65.56568  22.21577      323.2   0.4  0.44  2026-05-19       24       N21
#
#   instrument confidence version bright_ti5   frp daynight  \
# 0      VIIRS          n  2.0NRT     272.71  6.27        D
# 1      VIIRS          n  2.0NRT     277.32  3.76        N
# 2      VIIRS          n  2.0NRT     280.05  2.51        N
# 3      VIIRS          n  2.0NRT     280.05  2.51        N
# 4      VIIRS          n  2.0NRT     278.89  2.51        N
#
#                     geometry
# 0  POINT (77.25401 64.84473)
# 1  POINT (24.42774 64.64521)
# 2  POINT (22.22275 65.56101)
# 3  POINT (22.21415 65.56162)
# 4  POINT (22.21577 65.56568)
#
# Available columns:
# ['latitude', 'longitude', 'bright_ti4', 'scan', 'track', 'acq_date', 'acq_time', 'satellite', 'instrument', 'confidence', 'version', 'bright_ti5', 'frp', 'daynight', 'geometry']
#
# Step 8: GeoJSON successfully saved to:
# C:\Users\Damian\OneDrive - Universität Zürich UZH\26 FS\GEO876 - Spatial Programming\GEO876_Project\data\raw\wildfires_raw.geojson
#
# Step 9: Temporary files removed.

# %%
# =========================================================
# STEP 2 — PROCESS WILDFIRE DATA
# =========================================================

import process_wildfire_data

process_wildfire_data.main()
# Out:
# 2026-05-21 17:00:57,275 | INFO | ============================================================
# 2026-05-21 17:00:57,275 | INFO | STARTING WILDFIRE DATA PROCESSING
# 2026-05-21 17:00:57,276 | INFO | ============================================================
# 2026-05-21 17:00:57,276 | INFO | Loading wildfire data...
# 2026-05-21 17:00:58,544 | INFO | Loaded 66822 wildfire records.
# 2026-05-21 17:00:58,545 | INFO | Inspecting dataset...
# 2026-05-21 17:00:58,545 | INFO | CRS: EPSG:4326
# 2026-05-21 17:00:58,546 | INFO | Columns: ['latitude', 'longitude', 'bright_ti4', 'scan', 'track', 'acq_date', 'acq_time', 'satellite', 'instrument', 'confidence', 'version', 'bright_ti5', 'frp', 'daynight', 'geometry']
# 2026-05-21 17:00:58,550 | INFO | Geometry type(s): <StringArray>
# ['Point']
# Length: 1, dtype: str
# 2026-05-21 17:00:58,550 | INFO | Missing values:
# 2026-05-21 17:00:58,584 | INFO | latitude      0
# longitude     0
# bright_ti4    0
# scan          0
# track         0
# acq_date      0
# acq_time      0
# satellite     0
# instrument    0
# confidence    0
# version       0
# bright_ti5    0
# frp           0
# daynight      0
# geometry      0
# dtype: int64
# 2026-05-21 17:00:58,585 | INFO | Validating CRS...
# 2026-05-21 17:00:58,585 | INFO | Original CRS: EPSG:4326
# 2026-05-21 17:00:58,617 | INFO | Reprojected to: EPSG:3857
# 2026-05-21 17:00:58,623 | INFO | Cleaning columns...
# 2026-05-21 17:00:58,624 | INFO | Remaining columns: 7
# 2026-05-21 17:00:58,633 | INFO | Cleaning datatypes...
# 2026-05-21 17:00:58,686 | INFO | Removing invalid geometries...
# 2026-05-21 17:00:58,692 | INFO | Removed 0 invalid geometries.
# 2026-05-21 17:00:58,692 | INFO | Removing missing values...
# 2026-05-21 17:00:58,695 | INFO | Removed 0 rows with missing values.
# 2026-05-21 17:00:58,695 | INFO | Filtering confidence = ['n', 'h']
# 2026-05-21 17:00:58,711 | INFO | Removed 6259 low-confidence detections.
# 2026-05-21 17:00:58,714 | INFO | Adding temporal columns...
# 2026-05-21 17:00:58,717 | INFO | Final dataset summary:
# 2026-05-21 17:00:58,725 | INFO | None
# 2026-05-21 17:00:58,726 | INFO | Final number of records: 60563
# 2026-05-21 17:00:58,726 | INFO | Exporting processed dataset...
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 60563 entries, 0 to 66821
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   latitude    60563 non-null  float64
#  1   longitude   60563 non-null  float64
#  2   acq_date    60563 non-null  datetime64[ms]
#  3   acq_time    60563 non-null  str
#  4   confidence  60563 non-null  str
#  5   frp         60563 non-null  float64
#  6   geometry    60563 non-null  geometry
#  7   year        60563 non-null  int32
#  8   month       60563 non-null  int32
#  9   day         60563 non-null  int32
# dtypes: datetime64[ms](1), float64(3), geometry(1), int32(3), str(2)
# memory usage: 4.4 MB
# 2026-05-21 17:00:59,392 | INFO | Created 60,563 records
# 2026-05-21 17:00:59,483 | INFO | Processed data saved to:
# C:\Users\Damian\OneDrive - Universität Zürich UZH\26 FS\GEO876 - Spatial Programming\GEO876_Project\data\processed\wildfires_processed.gpkg
# 2026-05-21 17:00:59,484 | INFO | ============================================================
# 2026-05-21 17:00:59,484 | INFO | PROCESSING FINISHED SUCCESSFULLY
# 2026-05-21 17:00:59,485 | INFO | ============================================================

# %%
# =========================================================
# STEP 3 — SPATIAL RISK ANALYSIS
# =========================================================

import spatial_risk_analysis
# Out:
# Step 1: Loading wildfire data...
# 2026-05-21 17:01:00,060 | INFO | Created 1,088 records
# Total wildfire events: 60563
#
# Step 2: Filtering wildfire events with FRP > 50...
# High-intensity wildfire events: 1088
#
# Step 4: Filtering cities with population > 500,000...
# Large cities selected: 1430
#
# Step 6: Reprojecting datasets for distance analysis...
#
# Step 7: Calculating nearest city distances...
#
# Step 8: Classifying humanitarian risk levels...
#
# ===== RISK SUMMARY =====
# risk_level
# Low          997
# Moderate      63
# High          19
# Very High      9
# Name: count, dtype: int64
#
# Step 10: Exporting results...
# GPKG saved to: C:\Users\Damian\OneDrive - Universität Zürich UZH\26 FS\GEO876 - Spatial Programming\GEO876_Project\data\outputs\high_risk_wildfires.gpkg
# CSV saved to: C:\Users\Damian\OneDrive - Universität Zürich UZH\26 FS\GEO876 - Spatial Programming\GEO876_Project\data\outputs\high_risk_wildfires.csv
#
# Spatial wildfire risk analysis completed successfully.

# %%
#=========================================================
# STEP 4 — CREATE INTERACTIVE MAP
#=========================================================

import importlib
import create_map

print("\nMap was imported successfully. Map is being loaded...")

importlib.reload(create_map)
# Out:
# Loading wildfire risk analysis data...
# Loaded 1088 wildfire events
# Calculating risk scores...
# Creating base map...
# Creating classification layers...
# Adding wildfire events to map...
# Adding cities to map...
# Saving interactive map...
# Done!
# Map saved to: C:\Users\Damian\OneDrive - Universität Zürich UZH\26 FS\GEO876 - Spatial Programming\GEO876_Project\maps\wildfire_interactive_map.html
#
# Map was imported successfully. Map is being loaded...
# Loading wildfire risk analysis data...
# Loaded 1088 wildfire events
# Calculating risk scores...
# Creating base map...
# Creating classification layers...
# Adding wildfire events to map...
# Adding cities to map...
# Saving interactive map...
# Done!
# Map saved to: C:\Users\Damian\OneDrive - Universität Zürich UZH\26 FS\GEO876 - Spatial Programming\GEO876_Project\maps\wildfire_interactive_map.html
# <module 'create_map' from 'c:\\Users\\Damian\\OneDrive - Universität Zürich UZH\\26 FS\\GEO876 - Spatial Programming\\GEO876_Project\\notebooks\\../src\\create_map.py'>
